# %% [markdown]
# # Process the Unsplash dataset with CLIP
#
# This notebook processes all the downloaded photos using OpenAI's [CLIP neural network](https://github.com/openai/CLIP). For each image we get a feature vector containing 512 float numbers, which we will store in a file. These feature vectors will be used later to compare them to the text feature vectors.
#
# This step will be significantly faster if you have a GPU, but it will also work on the CPU.

# %% [markdown]
# ## Load the photos
#
# Load all photos from the folder they were stored.

# %%
from pathlib import Path

# Set the path to the photos
dataset_version = "bso" 
photos_path = Path("/home/cluster/fkraeu/data/bso-image-segmentation/data/images")

# List all JPGs in the folder
photos_files = list(photos_path.glob("*.jpg"))

# Print some statistics
print(f"Photos found: {len(photos_files)}")
# Out:
# Photos found: 27473

# %% [markdown]
# ## Load the CLIP net
#
# Load the CLIP net and define the function that computes the feature vectors

# %%
import clip
import torch
from PIL import Image

# Load the open CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# Function that computes the feature vectors for a batch of images
def compute_clip_features(photos_batch):
    # Load all the photos from the files
    photos = [Image.open(photo_file) for photo_file in photos_batch]
    
    # Preprocess all photos
    photos_preprocessed = torch.stack([preprocess(photo) for photo in photos]).to(device)

    with torch.no_grad():
        # Encode the photos batch to compute the feature vectors and normalize them
        photos_features = model.encode_image(photos_preprocessed)
        photos_features /= photos_features.norm(dim=-1, keepdim=True)

    # Transfer the feature vectors back to the CPU and convert to numpy
    return photos_features.cpu().numpy()

# %% [markdown]
# ## Process all photos
#
# Now we need to compute the features for all photos. We will do that in batches, because it is much more efficient. You should tune the batch size so that it fits on your GPU. The processing on the GPU is fairly fast, so the bottleneck will probably be loading the photos from the disk.
#
# In this step the feature vectors and the photo IDs of each batch will be saved to a file separately. This makes the whole process more robust. We will merge the data later.

# %%
import math
import numpy as np
import pandas as pd

# Define the batch size so that it fits on your GPU. You can also do the processing on the CPU, but it will be slower.
batch_size = 16

# Path where the feature vectors will be stored
features_path = Path("unsplash-dataset") / dataset_version / "features"

# Compute how many batches are needed
batches = math.ceil(len(photos_files) / batch_size)

# Process each batch
for i in range(batches):
    print(f"Processing batch {i+1}/{batches}")

    batch_ids_path = features_path / f"{i:010d}.csv"
    batch_features_path = features_path / f"{i:010d}.npy"
    
    # Only do the processing if the batch wasn't processed yet
    if not batch_features_path.exists():
        try:
            # Select the photos for the current batch
            batch_files = photos_files[i*batch_size : (i+1)*batch_size]

            # Compute the features and save to a numpy file
            batch_features = compute_clip_features(batch_files)
            np.save(batch_features_path, batch_features)

            # Save the photo IDs to a CSV file
            photo_ids = [photo_file.name.split(".")[0] for photo_file in batch_files]
            photo_ids_data = pd.DataFrame(photo_ids, columns=['photo_id'])
            photo_ids_data.to_csv(batch_ids_path, index=False)
        except:
            # Catch problems with the processing to make the process more robust
            print(f'Problem with batch {i}')
# Out:
# Processing batch 1/1718
# Processing batch 2/1718
# Processing batch 3/1718
# Processing batch 4/1718
# Processing batch 5/1718
# Processing batch 6/1718
# Processing batch 7/1718
# Processing batch 8/1718
# Processing batch 9/1718
# Processing batch 10/1718
# Processing batch 11/1718
# Processing batch 12/1718
# Processing batch 13/1718
# Processing batch 14/1718
# Processing batch 15/1718
# Processing batch 16/1718
# Processing batch 17/1718
# Processing batch 18/1718
# Processing batch 19/1718
# Processing batch 20/1718
# Processing batch 21/1718
# Processing batch 22/1718
# Processing batch 23/1718
# Processing batch 24/1718
# Processing batch 25/1718
# Processing batch 26/1718
# Processing batch 27/1718
# Processing batch 28/1718
# Processing batch 29/1718
# Processing batch 30/1718
# Processing batch 31/1718
# Processing batch 32/1718
# Processing batch 33/1718
# Processing batch 34/1718
# Processing batch 35/1718
# Processing batch 36/1718
# Processing batch 37/1718
# Processing batch 38/1718
# Processing batch 39/1718
# Processing batch 40/1718
# Processing batch 41/1718
# Processing batch 42/1718
# Processing batch 43/1718
# Processing batch 44/1718
# Processing batch 45/1718
# Processing batch 46/1718
# Processing batch 47/1718
# Processing batch 48/1718
# Processing batch 49/1718
# Processing batch 50/1718
# Processing batch 51/1718
# Processing batch 52/1718
# Processing batch 53/1718
# Processing batch 54/1718
# Processing batch 55/1718
# Processing batch 56/1718
# Processing batch 57/1718
# Processing batch 58/1718
# Processing batch 59/1718
# Processing batch 60/1718
# Processing batch 61/1718
# Processing batch 62/1718
# Processing batch 63/1718
# Processing batch 64/1718
# Processing batch 65/1718
# Processing batch 66/1718
# Processing batch 67/1718
# Processing batch 68/1718
# Processing batch 69/1718
# Processing batch 70/1718
# Processing batch 71/1718
# Processing batch 72/1718
# Processing batch 73/1718
# Processing batch 74/1718
# Processing batch 75/1718
# Processing batch 76/1718
# Processing batch 77/1718
# Processing batch 78/1718
# Processing batch 79/1718
# Processing batch 80/1718
# Processing batch 81/1718
# Processing batch 82/1718
# Processing batch 83/1718
# Processing batch 84/1718
# Processing batch 85/1718
# Processing batch 86/1718
# Processing batch 87/1718
# Processing batch 88/1718
# Processing batch 89/1718
# Processing batch 90/1718
# Processing batch 91/1718
# Processing batch 92/1718
# Processing batch 93/1718
# Processing batch 94/1718
# Processing batch 95/1718
# Processing batch 96/1718
# Processing batch 97/1718
# Processing batch 98/1718
# Processing batch 99/1718
# Processing batch 100/1718
# Processing batch 101/1718
# Processing batch 102/1718
# Processing batch 103/1718
# Processing batch 104/1718
# Processing batch 105/1718
# Processing batch 106/1718
# Processing batch 107/1718
# Processing batch 108/1718
# Processing batch 109/1718
# Processing batch 110/1718
# Processing batch 111/1718
# Processing batch 112/1718
# Processing batch 113/1718
# Processing batch 114/1718
# Processing batch 115/1718
# Processing batch 116/1718
# Processing batch 117/1718
# Processing batch 118/1718
# Processing batch 119/1718
# Processing batch 120/1718
# Processing batch 121/1718
# Processing batch 122/1718
# Processing batch 123/1718
# Processing batch 124/1718
# Processing batch 125/1718
# Processing batch 126/1718
# Processing batch 127/1718
# Processing batch 128/1718
# Processing batch 129/1718
# Processing batch 130/1718
# Processing batch 131/1718
# Processing batch 132/1718
# Processing batch 133/1718
# Processing batch 134/1718
# Processing batch 135/1718
# Processing batch 136/1718
# Processing batch 137/1718
# Processing batch 138/1718
# Processing batch 139/1718
# Processing batch 140/1718
# Processing batch 141/1718
# Processing batch 142/1718
# Processing batch 143/1718
# Processing batch 144/1718
# Processing batch 145/1718
# Processing batch 146/1718
# Processing batch 147/1718
# Processing batch 148/1718
# Processing batch 149/1718
# Processing batch 150/1718
# Processing batch 151/1718
# Processing batch 152/1718
# Processing batch 153/1718
# Processing batch 154/1718
# Processing batch 155/1718
# Processing batch 156/1718
# Processing batch 157/1718
# Processing batch 158/1718
# Processing batch 159/1718
# Processing batch 160/1718
# Processing batch 161/1718
# Processing batch 162/1718
# Processing batch 163/1718
# Processing batch 164/1718
# Processing batch 165/1718
# Processing batch 166/1718
# Processing batch 167/1718
# Processing batch 168/1718
# Processing batch 169/1718
# Processing batch 170/1718
# Processing batch 171/1718
# Processing batch 172/1718
# Processing batch 173/1718
# Processing batch 174/1718
# Processing batch 175/1718
# Processing batch 176/1718
# Processing batch 177/1718
# Processing batch 178/1718
# Processing batch 179/1718
# Processing batch 180/1718
# Processing batch 181/1718
# Processing batch 182/1718
# Processing batch 183/1718
# Processing batch 184/1718
# Processing batch 185/1718
# Processing batch 186/1718
# Processing batch 187/1718
# Processing batch 188/1718
# Processing batch 189/1718
# Processing batch 190/1718
# Processing batch 191/1718
# Processing batch 192/1718
# Processing batch 193/1718
# Processing batch 194/1718
# Processing batch 195/1718
# Processing batch 196/1718
# Processing batch 197/1718
# Processing batch 198/1718
# Processing batch 199/1718
# Processing batch 200/1718
# Processing batch 201/1718
# Processing batch 202/1718
# Processing batch 203/1718
# Processing batch 204/1718
# Processing batch 205/1718
# Processing batch 206/1718
# Processing batch 207/1718
# Processing batch 208/1718
# Processing batch 209/1718
# Processing batch 210/1718
# Processing batch 211/1718
# Processing batch 212/1718
# Processing batch 213/1718
# Processing batch 214/1718
# Processing batch 215/1718
# Processing batch 216/1718
# Processing batch 217/1718
# Processing batch 218/1718
# Processing batch 219/1718
# Processing batch 220/1718
# Processing batch 221/1718
# Processing batch 222/1718
# Processing batch 223/1718
# Processing batch 224/1718
# Processing batch 225/1718
# Processing batch 226/1718
# Processing batch 227/1718
# Processing batch 228/1718
# Processing batch 229/1718
# Processing batch 230/1718
# Processing batch 231/1718
# Processing batch 232/1718
# Processing batch 233/1718
# Processing batch 234/1718
# Processing batch 235/1718
# Processing batch 236/1718
# Processing batch 237/1718
# Processing batch 238/1718
# Processing batch 239/1718
# Processing batch 240/1718
# Processing batch 241/1718
# Processing batch 242/1718
# Processing batch 243/1718
# Processing batch 244/1718
# Processing batch 245/1718
# Processing batch 246/1718
# Processing batch 247/1718
# Processing batch 248/1718
# Processing batch 249/1718
# Processing batch 250/1718
# Processing batch 251/1718
# Processing batch 252/1718
# Processing batch 253/1718
# Processing batch 254/1718
# Processing batch 255/1718
# Processing batch 256/1718
# Processing batch 257/1718
# Processing batch 258/1718
# Processing batch 259/1718
# Processing batch 260/1718
# Processing batch 261/1718
# Processing batch 262/1718
# Processing batch 263/1718
# Processing batch 264/1718
# Processing batch 265/1718
# Processing batch 266/1718
# Processing batch 267/1718
# Processing batch 268/1718
# Processing batch 269/1718
# Processing batch 270/1718
# Processing batch 271/1718
# Processing batch 272/1718
# Processing batch 273/1718
# Processing batch 274/1718
# Processing batch 275/1718
# Processing batch 276/1718
# Processing batch 277/1718
# Processing batch 278/1718
# Processing batch 279/1718
# Processing batch 280/1718
# Processing batch 281/1718
# Processing batch 282/1718
# Processing batch 283/1718
# Processing batch 284/1718
# Processing batch 285/1718
# Processing batch 286/1718
# Processing batch 287/1718
# Processing batch 288/1718
# Processing batch 289/1718
# Processing batch 290/1718
# Processing batch 291/1718
# Processing batch 292/1718
# Processing batch 293/1718
# Processing batch 294/1718
# Processing batch 295/1718
# Processing batch 296/1718
# Processing batch 297/1718
# Processing batch 298/1718
# Processing batch 299/1718
# Processing batch 300/1718
# Processing batch 301/1718
# Processing batch 302/1718
# Processing batch 303/1718
# Processing batch 304/1718
# Processing batch 305/1718
# Processing batch 306/1718
# Processing batch 307/1718
# Processing batch 308/1718
# Processing batch 309/1718
# Processing batch 310/1718
# Processing batch 311/1718
# Processing batch 312/1718
# Processing batch 313/1718
# Processing batch 314/1718
# Processing batch 315/1718
# Processing batch 316/1718
# Processing batch 317/1718
# Processing batch 318/1718
# Processing batch 319/1718
# Processing batch 320/1718
# Processing batch 321/1718
# Processing batch 322/1718
# Processing batch 323/1718
# Processing batch 324/1718
# Processing batch 325/1718
# Processing batch 326/1718
# Processing batch 327/1718
# Processing batch 328/1718
# Processing batch 329/1718
# Processing batch 330/1718
# Processing batch 331/1718
# Processing batch 332/1718
# Processing batch 333/1718
# Processing batch 334/1718
# Processing batch 335/1718
# Processing batch 336/1718
# Processing batch 337/1718
# Processing batch 338/1718
# Processing batch 339/1718
# Processing batch 340/1718
# Processing batch 341/1718
# Processing batch 342/1718
# Processing batch 343/1718
# Processing batch 344/1718
# Processing batch 345/1718
# Processing batch 346/1718
# Processing batch 347/1718
# Processing batch 348/1718
# Processing batch 349/1718
# Processing batch 350/1718
# Processing batch 351/1718
# Processing batch 352/1718
# Processing batch 353/1718
# Processing batch 354/1718
# Processing batch 355/1718
# Processing batch 356/1718
# Processing batch 357/1718
# Processing batch 358/1718
# Processing batch 359/1718
# Processing batch 360/1718
# Processing batch 361/1718
# Processing batch 362/1718
# Processing batch 363/1718
# Processing batch 364/1718
# Processing batch 365/1718
# Processing batch 366/1718
# Processing batch 367/1718
# Processing batch 368/1718
# Processing batch 369/1718
# Processing batch 370/1718
# Processing batch 371/1718
# Processing batch 372/1718
# Processing batch 373/1718
# Processing batch 374/1718
# Processing batch 375/1718
# Processing batch 376/1718
# Processing batch 377/1718
# Processing batch 378/1718
# Processing batch 379/1718
# Processing batch 380/1718
# Processing batch 381/1718
# Processing batch 382/1718
# Processing batch 383/1718
# Processing batch 384/1718
# Processing batch 385/1718
# Processing batch 386/1718
# Processing batch 387/1718
# Processing batch 388/1718
# Processing batch 389/1718
# Processing batch 390/1718
# Processing batch 391/1718
# Processing batch 392/1718
# Processing batch 393/1718
# Processing batch 394/1718
# Processing batch 395/1718
# Processing batch 396/1718
# Processing batch 397/1718
# Processing batch 398/1718
# Processing batch 399/1718
# Processing batch 400/1718
# Processing batch 401/1718
# Processing batch 402/1718
# Processing batch 403/1718
# Processing batch 404/1718
# Processing batch 405/1718
# Processing batch 406/1718
# Processing batch 407/1718
# Processing batch 408/1718
# Processing batch 409/1718
# Processing batch 410/1718
# Processing batch 411/1718
# Processing batch 412/1718
# Processing batch 413/1718
# Processing batch 414/1718
# Processing batch 415/1718
# Processing batch 416/1718
# Processing batch 417/1718
# Processing batch 418/1718
# Processing batch 419/1718
# Processing batch 420/1718
# Processing batch 421/1718
# Processing batch 422/1718
# Processing batch 423/1718
# Processing batch 424/1718
# Processing batch 425/1718
# Processing batch 426/1718
# Processing batch 427/1718
# Processing batch 428/1718
# Processing batch 429/1718
# Processing batch 430/1718
# Processing batch 431/1718
# Processing batch 432/1718
# Processing batch 433/1718
# Processing batch 434/1718
# Processing batch 435/1718
# Processing batch 436/1718
# Processing batch 437/1718
# Processing batch 438/1718
# Processing batch 439/1718
# Processing batch 440/1718
# Processing batch 441/1718
# Processing batch 442/1718
# Processing batch 443/1718
# Processing batch 444/1718
# Processing batch 445/1718
# Processing batch 446/1718
# Processing batch 447/1718
# Processing batch 448/1718
# Processing batch 449/1718
# Processing batch 450/1718
# Processing batch 451/1718
# Processing batch 452/1718
# Processing batch 453/1718
# Processing batch 454/1718
# Processing batch 455/1718
# Processing batch 456/1718
# Processing batch 457/1718
# Processing batch 458/1718
# Processing batch 459/1718
# Processing batch 460/1718
# Processing batch 461/1718
# Processing batch 462/1718
# Processing batch 463/1718
# Processing batch 464/1718
# Processing batch 465/1718
# Processing batch 466/1718
# Processing batch 467/1718
# Processing batch 468/1718
# Processing batch 469/1718
# Processing batch 470/1718
# Processing batch 471/1718
# Processing batch 472/1718
# Processing batch 473/1718
# Processing batch 474/1718
# Processing batch 475/1718
# Processing batch 476/1718
# Processing batch 477/1718
# Processing batch 478/1718
# Processing batch 479/1718
# Processing batch 480/1718
# Processing batch 481/1718
# Processing batch 482/1718
# Processing batch 483/1718
# Processing batch 484/1718
# Processing batch 485/1718
# Processing batch 486/1718
# Processing batch 487/1718
# Processing batch 488/1718
# Processing batch 489/1718
# Processing batch 490/1718
# Processing batch 491/1718
# Processing batch 492/1718
# Processing batch 493/1718
# Processing batch 494/1718
# Processing batch 495/1718
# Processing batch 496/1718
# Processing batch 497/1718
# Processing batch 498/1718
# Processing batch 499/1718
# Processing batch 500/1718
# Processing batch 501/1718
# Processing batch 502/1718
# Processing batch 503/1718
# Processing batch 504/1718
# Processing batch 505/1718
# Processing batch 506/1718
# Processing batch 507/1718
# Processing batch 508/1718
# Processing batch 509/1718
# Processing batch 510/1718
# Processing batch 511/1718
# Processing batch 512/1718
# Processing batch 513/1718
# Processing batch 514/1718
# Processing batch 515/1718
# Processing batch 516/1718
# Processing batch 517/1718
# Processing batch 518/1718
# Processing batch 519/1718
# Processing batch 520/1718
# Processing batch 521/1718
# Processing batch 522/1718
# Processing batch 523/1718
# Processing batch 524/1718
# Processing batch 525/1718
# Processing batch 526/1718
# Processing batch 527/1718
# Processing batch 528/1718
# Processing batch 529/1718
# Processing batch 530/1718
# Processing batch 531/1718
# Processing batch 532/1718
# Processing batch 533/1718
# Processing batch 534/1718
# Processing batch 535/1718
# Processing batch 536/1718
# Processing batch 537/1718
# Processing batch 538/1718
# Processing batch 539/1718
# Processing batch 540/1718
# Processing batch 541/1718
# Processing batch 542/1718
# Processing batch 543/1718
# Processing batch 544/1718
# Processing batch 545/1718
# Processing batch 546/1718
# Processing batch 547/1718
# Processing batch 548/1718
# Processing batch 549/1718
# Processing batch 550/1718
# Processing batch 551/1718
# Processing batch 552/1718
# Processing batch 553/1718
# Processing batch 554/1718
# Processing batch 555/1718
# Processing batch 556/1718
# Processing batch 557/1718
# Processing batch 558/1718
# Processing batch 559/1718
# Processing batch 560/1718
# Processing batch 561/1718
# Processing batch 562/1718
# Processing batch 563/1718
# Processing batch 564/1718
# Processing batch 565/1718
# Processing batch 566/1718
# Processing batch 567/1718
# Processing batch 568/1718
# Processing batch 569/1718
# Processing batch 570/1718
# Processing batch 571/1718
# Processing batch 572/1718
# Processing batch 573/1718
# Processing batch 574/1718
# Processing batch 575/1718
# Processing batch 576/1718
# Processing batch 577/1718
# Processing batch 578/1718
# Processing batch 579/1718
# Processing batch 580/1718
# Processing batch 581/1718
# Processing batch 582/1718
# Processing batch 583/1718
# Processing batch 584/1718
# Processing batch 585/1718
# Processing batch 586/1718
# Processing batch 587/1718
# Processing batch 588/1718
# Processing batch 589/1718
# Processing batch 590/1718
# Processing batch 591/1718
# Processing batch 592/1718
# Processing batch 593/1718
# Processing batch 594/1718
# Processing batch 595/1718
# Processing batch 596/1718
# Processing batch 597/1718
# Processing batch 598/1718
# Processing batch 599/1718
# Processing batch 600/1718
# Processing batch 601/1718
# Processing batch 602/1718
# Processing batch 603/1718
# Processing batch 604/1718
# Processing batch 605/1718
# Processing batch 606/1718
# Processing batch 607/1718
# Processing batch 608/1718
# Processing batch 609/1718
# Processing batch 610/1718
# Processing batch 611/1718
# Processing batch 612/1718
# Processing batch 613/1718
# Processing batch 614/1718
# Processing batch 615/1718
# Processing batch 616/1718
# Processing batch 617/1718
# Processing batch 618/1718
# Processing batch 619/1718
# Processing batch 620/1718
# Processing batch 621/1718
# Processing batch 622/1718
# Processing batch 623/1718
# Processing batch 624/1718
# Processing batch 625/1718
# Processing batch 626/1718
# Processing batch 627/1718
# Processing batch 628/1718
# Processing batch 629/1718
# Processing batch 630/1718
# Processing batch 631/1718
# Processing batch 632/1718
# Processing batch 633/1718
# Processing batch 634/1718
# Processing batch 635/1718
# Processing batch 636/1718
# Processing batch 637/1718
# Processing batch 638/1718
# Processing batch 639/1718
# Processing batch 640/1718
# Processing batch 641/1718
# Processing batch 642/1718
# Processing batch 643/1718
# Processing batch 644/1718
# Processing batch 645/1718
# Processing batch 646/1718
# Processing batch 647/1718
# Processing batch 648/1718
# Processing batch 649/1718
# Processing batch 650/1718
# Processing batch 651/1718
# Processing batch 652/1718
# Processing batch 653/1718
# Processing batch 654/1718
# Processing batch 655/1718
# Processing batch 656/1718
# Processing batch 657/1718
# Processing batch 658/1718
# Processing batch 659/1718
# Processing batch 660/1718
# Processing batch 661/1718
# Processing batch 662/1718
# Processing batch 663/1718
# Processing batch 664/1718
# Processing batch 665/1718
# Processing batch 666/1718
# Processing batch 667/1718
# Processing batch 668/1718
# Processing batch 669/1718
# Processing batch 670/1718
# Processing batch 671/1718
# Processing batch 672/1718
# Processing batch 673/1718
# Processing batch 674/1718
# Processing batch 675/1718
# Processing batch 676/1718
# Processing batch 677/1718
# Processing batch 678/1718
# Processing batch 679/1718
# Processing batch 680/1718
# Processing batch 681/1718
# Processing batch 682/1718
# Processing batch 683/1718
# Processing batch 684/1718
# Processing batch 685/1718
# Processing batch 686/1718
# Processing batch 687/1718
# Processing batch 688/1718
# Processing batch 689/1718
# Processing batch 690/1718
# Processing batch 691/1718
# Processing batch 692/1718
# Processing batch 693/1718
# Processing batch 694/1718
# Processing batch 695/1718
# Processing batch 696/1718
# Processing batch 697/1718
# Processing batch 698/1718
# Processing batch 699/1718
# Processing batch 700/1718
# Processing batch 701/1718
# Processing batch 702/1718
# Processing batch 703/1718
# Processing batch 704/1718
# Processing batch 705/1718
# Processing batch 706/1718
# Processing batch 707/1718
# Processing batch 708/1718
# Processing batch 709/1718
# Processing batch 710/1718
# Processing batch 711/1718
# Processing batch 712/1718
# Processing batch 713/1718
# Processing batch 714/1718
# Processing batch 715/1718
# Processing batch 716/1718
# Processing batch 717/1718
# Processing batch 718/1718
# Processing batch 719/1718
# Processing batch 720/1718
# Processing batch 721/1718
# Processing batch 722/1718
# Processing batch 723/1718
# Processing batch 724/1718
# Processing batch 725/1718
# Processing batch 726/1718
# Processing batch 727/1718
# Processing batch 728/1718
# Processing batch 729/1718
# Processing batch 730/1718
# Processing batch 731/1718
# Processing batch 732/1718
# Processing batch 733/1718
# Processing batch 734/1718
# Processing batch 735/1718
# Processing batch 736/1718
# Processing batch 737/1718
# Processing batch 738/1718
# Processing batch 739/1718
# Processing batch 740/1718
# Processing batch 741/1718
# Processing batch 742/1718
# Processing batch 743/1718
# Processing batch 744/1718
# Processing batch 745/1718
# Processing batch 746/1718
# Processing batch 747/1718
# Processing batch 748/1718
# Processing batch 749/1718
# Processing batch 750/1718
# Processing batch 751/1718
# Processing batch 752/1718
# Processing batch 753/1718
# Processing batch 754/1718
# Processing batch 755/1718
# Processing batch 756/1718
# Processing batch 757/1718
# Processing batch 758/1718
# Processing batch 759/1718
# Processing batch 760/1718
# Processing batch 761/1718
# Processing batch 762/1718
# Processing batch 763/1718
# Processing batch 764/1718
# Processing batch 765/1718
# Processing batch 766/1718
# Processing batch 767/1718
# Processing batch 768/1718
# Processing batch 769/1718
# Processing batch 770/1718
# Processing batch 771/1718
# Processing batch 772/1718
# Processing batch 773/1718
# Processing batch 774/1718
# Processing batch 775/1718
# Processing batch 776/1718
# Processing batch 777/1718
# Processing batch 778/1718
# Processing batch 779/1718
# Processing batch 780/1718
# Processing batch 781/1718
# Processing batch 782/1718
# Processing batch 783/1718
# Processing batch 784/1718
# Processing batch 785/1718
# Processing batch 786/1718
# Processing batch 787/1718
# Processing batch 788/1718
# Processing batch 789/1718
# Processing batch 790/1718
# Processing batch 791/1718
# Processing batch 792/1718
# Processing batch 793/1718
# Processing batch 794/1718
# Processing batch 795/1718
# Processing batch 796/1718
# Processing batch 797/1718
# Processing batch 798/1718
# Processing batch 799/1718
# Processing batch 800/1718
# Processing batch 801/1718
# Processing batch 802/1718
# Processing batch 803/1718
# Processing batch 804/1718
# Processing batch 805/1718
# Processing batch 806/1718
# Processing batch 807/1718
# Processing batch 808/1718
# Processing batch 809/1718
# Processing batch 810/1718
# Processing batch 811/1718
# Processing batch 812/1718
# Processing batch 813/1718
# Processing batch 814/1718
# Processing batch 815/1718
# Processing batch 816/1718
# Processing batch 817/1718
# Processing batch 818/1718
# Processing batch 819/1718
# Processing batch 820/1718
# Processing batch 821/1718
# Processing batch 822/1718
# Processing batch 823/1718
# Processing batch 824/1718
# Processing batch 825/1718
# Processing batch 826/1718
# Processing batch 827/1718
# Processing batch 828/1718
# Processing batch 829/1718
# Processing batch 830/1718
# Processing batch 831/1718
# Processing batch 832/1718
# Processing batch 833/1718
# Processing batch 834/1718
# Processing batch 835/1718
# Processing batch 836/1718
# Processing batch 837/1718
# Processing batch 838/1718
# Processing batch 839/1718
# Processing batch 840/1718
# Processing batch 841/1718
# Processing batch 842/1718
# Processing batch 843/1718
# Processing batch 844/1718
# Processing batch 845/1718
# Processing batch 846/1718
# Processing batch 847/1718
# Processing batch 848/1718
# Processing batch 849/1718
# Processing batch 850/1718
# Processing batch 851/1718
# Processing batch 852/1718
# Processing batch 853/1718
# Processing batch 854/1718
# Processing batch 855/1718
# Processing batch 856/1718
# Processing batch 857/1718
# Processing batch 858/1718
# Processing batch 859/1718
# Processing batch 860/1718
# Processing batch 861/1718
# Processing batch 862/1718
# Processing batch 863/1718
# Processing batch 864/1718
# Processing batch 865/1718
# Processing batch 866/1718
# Processing batch 867/1718
# Processing batch 868/1718
# Processing batch 869/1718
# Processing batch 870/1718
# Processing batch 871/1718
# Processing batch 872/1718
# Processing batch 873/1718
# Processing batch 874/1718
# Processing batch 875/1718
# Processing batch 876/1718
# Processing batch 877/1718
# Processing batch 878/1718
# Processing batch 879/1718
# Processing batch 880/1718
# Processing batch 881/1718
# Processing batch 882/1718
# Processing batch 883/1718
# Processing batch 884/1718
# Processing batch 885/1718
# Processing batch 886/1718
# Processing batch 887/1718
# Processing batch 888/1718
# Processing batch 889/1718
# Processing batch 890/1718
# Processing batch 891/1718
# Processing batch 892/1718
# Processing batch 893/1718
# Processing batch 894/1718
# Processing batch 895/1718
# Processing batch 896/1718
# Processing batch 897/1718
# Processing batch 898/1718
# Processing batch 899/1718
# Processing batch 900/1718
# Processing batch 901/1718
# Processing batch 902/1718
# Processing batch 903/1718
# Processing batch 904/1718
# Processing batch 905/1718
# Processing batch 906/1718
# Processing batch 907/1718
# Processing batch 908/1718
# Processing batch 909/1718
# Processing batch 910/1718
# Processing batch 911/1718
# Processing batch 912/1718
# Processing batch 913/1718
# Processing batch 914/1718
# Processing batch 915/1718
# Processing batch 916/1718
# Processing batch 917/1718
# Processing batch 918/1718
# Processing batch 919/1718
# Processing batch 920/1718
# Processing batch 921/1718
# Processing batch 922/1718
# Processing batch 923/1718
# Processing batch 924/1718
# Processing batch 925/1718
# Processing batch 926/1718
# Processing batch 927/1718
# Processing batch 928/1718
# Processing batch 929/1718
# Processing batch 930/1718
# Processing batch 931/1718
# Processing batch 932/1718
# Processing batch 933/1718
# Processing batch 934/1718
# Processing batch 935/1718
# Processing batch 936/1718
# Processing batch 937/1718
# Processing batch 938/1718
# Processing batch 939/1718
# Processing batch 940/1718
# Processing batch 941/1718
# Processing batch 942/1718
# Processing batch 943/1718
# Processing batch 944/1718
# Processing batch 945/1718
# Processing batch 946/1718
# Processing batch 947/1718
# Processing batch 948/1718
# Processing batch 949/1718
# Processing batch 950/1718
# Processing batch 951/1718
# Processing batch 952/1718
# Processing batch 953/1718
# Processing batch 954/1718
# Processing batch 955/1718
# Processing batch 956/1718
# Processing batch 957/1718
# Processing batch 958/1718
# Processing batch 959/1718
# Processing batch 960/1718
# Processing batch 961/1718
# Processing batch 962/1718
# Processing batch 963/1718
# Processing batch 964/1718
# Processing batch 965/1718
# Processing batch 966/1718
# Processing batch 967/1718
# Processing batch 968/1718
# Processing batch 969/1718
# Processing batch 970/1718
# Processing batch 971/1718
# Processing batch 972/1718
# Processing batch 973/1718
# Processing batch 974/1718
# Processing batch 975/1718
# Processing batch 976/1718
# Processing batch 977/1718
# Processing batch 978/1718
# Processing batch 979/1718
# Processing batch 980/1718
# Processing batch 981/1718
# Processing batch 982/1718
# Processing batch 983/1718
# Processing batch 984/1718
# Processing batch 985/1718
# Processing batch 986/1718
# Processing batch 987/1718
# Processing batch 988/1718
# Processing batch 989/1718
# Processing batch 990/1718
# Processing batch 991/1718
# Processing batch 992/1718
# Processing batch 993/1718
# Processing batch 994/1718
# Processing batch 995/1718
# Processing batch 996/1718
# Processing batch 997/1718
# Processing batch 998/1718
# Processing batch 999/1718
# Processing batch 1000/1718
# Processing batch 1001/1718
# Processing batch 1002/1718
# Processing batch 1003/1718
# Processing batch 1004/1718
# Processing batch 1005/1718
# Processing batch 1006/1718
# Processing batch 1007/1718
# Processing batch 1008/1718
# Processing batch 1009/1718
# Processing batch 1010/1718
# Processing batch 1011/1718
# Processing batch 1012/1718
# Processing batch 1013/1718
# Processing batch 1014/1718
# Processing batch 1015/1718
# Processing batch 1016/1718
# Processing batch 1017/1718
# Processing batch 1018/1718
# Processing batch 1019/1718
# Processing batch 1020/1718
# Processing batch 1021/1718
# Processing batch 1022/1718
# Processing batch 1023/1718
# Processing batch 1024/1718
# Processing batch 1025/1718
# Processing batch 1026/1718
# Processing batch 1027/1718
# Processing batch 1028/1718
# Processing batch 1029/1718
# Processing batch 1030/1718
# Processing batch 1031/1718
# Processing batch 1032/1718
# Processing batch 1033/1718
# Processing batch 1034/1718
# Processing batch 1035/1718
# Processing batch 1036/1718
# Processing batch 1037/1718
# Processing batch 1038/1718
# Processing batch 1039/1718
# Processing batch 1040/1718
# Processing batch 1041/1718
# Processing batch 1042/1718
# Processing batch 1043/1718
# Processing batch 1044/1718
# Processing batch 1045/1718
# Processing batch 1046/1718
# Processing batch 1047/1718
# Processing batch 1048/1718
# Processing batch 1049/1718
# Processing batch 1050/1718
# Processing batch 1051/1718
# Processing batch 1052/1718
# Processing batch 1053/1718
# Processing batch 1054/1718
# Processing batch 1055/1718
# Processing batch 1056/1718
# Processing batch 1057/1718
# Processing batch 1058/1718
# Processing batch 1059/1718
# Processing batch 1060/1718
# Processing batch 1061/1718
# Processing batch 1062/1718
# Processing batch 1063/1718
# Processing batch 1064/1718
# Processing batch 1065/1718
# Processing batch 1066/1718
# Processing batch 1067/1718
# Processing batch 1068/1718
# Processing batch 1069/1718
# Processing batch 1070/1718
# Processing batch 1071/1718
# Processing batch 1072/1718
# Processing batch 1073/1718
# Processing batch 1074/1718
# Processing batch 1075/1718
# Processing batch 1076/1718
# Processing batch 1077/1718
# Processing batch 1078/1718
# Processing batch 1079/1718
# Processing batch 1080/1718
# Processing batch 1081/1718
# Processing batch 1082/1718
# Processing batch 1083/1718
# Processing batch 1084/1718
# Processing batch 1085/1718
# Processing batch 1086/1718
# Processing batch 1087/1718
# Processing batch 1088/1718
# Processing batch 1089/1718
# Processing batch 1090/1718
# Processing batch 1091/1718
# Processing batch 1092/1718
# Processing batch 1093/1718
# Processing batch 1094/1718
# Processing batch 1095/1718
# Processing batch 1096/1718
# Processing batch 1097/1718
# Processing batch 1098/1718
# Processing batch 1099/1718
# Processing batch 1100/1718
# Processing batch 1101/1718
# Processing batch 1102/1718
# Processing batch 1103/1718
# Processing batch 1104/1718
# Processing batch 1105/1718
# Processing batch 1106/1718
# Processing batch 1107/1718
# Processing batch 1108/1718
# Processing batch 1109/1718
# Processing batch 1110/1718
# Processing batch 1111/1718
# Processing batch 1112/1718
# Processing batch 1113/1718
# Processing batch 1114/1718
# Processing batch 1115/1718
# Processing batch 1116/1718
# Processing batch 1117/1718
# Processing batch 1118/1718
# Processing batch 1119/1718
# Processing batch 1120/1718
# Processing batch 1121/1718
# Processing batch 1122/1718
# Processing batch 1123/1718
# Processing batch 1124/1718
# Processing batch 1125/1718
# Processing batch 1126/1718
# Processing batch 1127/1718
# Processing batch 1128/1718
# Processing batch 1129/1718
# Processing batch 1130/1718
# Processing batch 1131/1718
# Processing batch 1132/1718
# Processing batch 1133/1718
# Processing batch 1134/1718
# Processing batch 1135/1718
# Processing batch 1136/1718
# Processing batch 1137/1718
# Processing batch 1138/1718
# Processing batch 1139/1718
# Processing batch 1140/1718
# Processing batch 1141/1718
# Processing batch 1142/1718
# Processing batch 1143/1718
# Processing batch 1144/1718
# Processing batch 1145/1718
# Processing batch 1146/1718
# Processing batch 1147/1718
# Processing batch 1148/1718
# Processing batch 1149/1718
# Processing batch 1150/1718
# Processing batch 1151/1718
# Processing batch 1152/1718
# Processing batch 1153/1718
# Processing batch 1154/1718
# Processing batch 1155/1718
# Processing batch 1156/1718
# Processing batch 1157/1718
# Processing batch 1158/1718
# Processing batch 1159/1718
# Processing batch 1160/1718
# Processing batch 1161/1718
# Processing batch 1162/1718
# Processing batch 1163/1718
# Processing batch 1164/1718
# Processing batch 1165/1718
# Processing batch 1166/1718
# Processing batch 1167/1718
# Processing batch 1168/1718
# Processing batch 1169/1718
# Processing batch 1170/1718
# Processing batch 1171/1718
# Processing batch 1172/1718
# Processing batch 1173/1718
# Processing batch 1174/1718
# Processing batch 1175/1718
# Processing batch 1176/1718
# Processing batch 1177/1718
# Processing batch 1178/1718
# Processing batch 1179/1718
# Processing batch 1180/1718
# Processing batch 1181/1718
# Processing batch 1182/1718
# Processing batch 1183/1718
# Processing batch 1184/1718
# Processing batch 1185/1718
# Processing batch 1186/1718
# Processing batch 1187/1718
# Processing batch 1188/1718
# Processing batch 1189/1718
# Processing batch 1190/1718
# Processing batch 1191/1718
# Processing batch 1192/1718
# Processing batch 1193/1718
# Processing batch 1194/1718
# Processing batch 1195/1718
# Processing batch 1196/1718
# Processing batch 1197/1718
# Processing batch 1198/1718
# Processing batch 1199/1718
# Processing batch 1200/1718
# Processing batch 1201/1718
# Processing batch 1202/1718
# Processing batch 1203/1718
# Processing batch 1204/1718
# Processing batch 1205/1718
# Processing batch 1206/1718
# Processing batch 1207/1718
# Processing batch 1208/1718
# Processing batch 1209/1718
# Processing batch 1210/1718
# Processing batch 1211/1718
# Processing batch 1212/1718
# Processing batch 1213/1718
# Processing batch 1214/1718
# Processing batch 1215/1718
# Processing batch 1216/1718
# Processing batch 1217/1718
# Processing batch 1218/1718
# Processing batch 1219/1718
# Processing batch 1220/1718
# Processing batch 1221/1718
# Processing batch 1222/1718
# Processing batch 1223/1718
# Processing batch 1224/1718
# Processing batch 1225/1718
# Processing batch 1226/1718
# Processing batch 1227/1718
# Processing batch 1228/1718
# Processing batch 1229/1718
# Processing batch 1230/1718
# Processing batch 1231/1718
# Processing batch 1232/1718
# Processing batch 1233/1718
# Processing batch 1234/1718
# Processing batch 1235/1718
# Processing batch 1236/1718
# Processing batch 1237/1718
# Processing batch 1238/1718
# Processing batch 1239/1718
# Processing batch 1240/1718
# Processing batch 1241/1718
# Processing batch 1242/1718
# Processing batch 1243/1718
# Processing batch 1244/1718
# Processing batch 1245/1718
# Processing batch 1246/1718
# Processing batch 1247/1718
# Processing batch 1248/1718
# Processing batch 1249/1718
# Processing batch 1250/1718
# Processing batch 1251/1718
# Processing batch 1252/1718
# Processing batch 1253/1718
# Processing batch 1254/1718
# Processing batch 1255/1718
# Processing batch 1256/1718
# Processing batch 1257/1718
# Processing batch 1258/1718
# Processing batch 1259/1718
# Processing batch 1260/1718
# Processing batch 1261/1718
# Processing batch 1262/1718
# Processing batch 1263/1718
# Processing batch 1264/1718
# Processing batch 1265/1718
# Processing batch 1266/1718
# Processing batch 1267/1718
# Processing batch 1268/1718
# Processing batch 1269/1718
# Processing batch 1270/1718
# Processing batch 1271/1718
# Processing batch 1272/1718
# Processing batch 1273/1718
# Processing batch 1274/1718
# Processing batch 1275/1718
# Processing batch 1276/1718
# Processing batch 1277/1718
# Processing batch 1278/1718
# Processing batch 1279/1718
# Processing batch 1280/1718
# Processing batch 1281/1718
# Processing batch 1282/1718
# Processing batch 1283/1718
# Processing batch 1284/1718
# Processing batch 1285/1718
# Processing batch 1286/1718
# Processing batch 1287/1718
# Processing batch 1288/1718
# Processing batch 1289/1718
# Processing batch 1290/1718
# Processing batch 1291/1718
# Processing batch 1292/1718
# Processing batch 1293/1718
# Processing batch 1294/1718
# Processing batch 1295/1718
# Processing batch 1296/1718
# Processing batch 1297/1718
# Processing batch 1298/1718
# Processing batch 1299/1718
# Processing batch 1300/1718
# Processing batch 1301/1718
# Processing batch 1302/1718
# Processing batch 1303/1718
# Processing batch 1304/1718
# Processing batch 1305/1718
# Processing batch 1306/1718
# Processing batch 1307/1718
# Processing batch 1308/1718
# Processing batch 1309/1718
# Processing batch 1310/1718
# Processing batch 1311/1718
# Processing batch 1312/1718
# Processing batch 1313/1718
# Processing batch 1314/1718
# Processing batch 1315/1718
# Processing batch 1316/1718
# Processing batch 1317/1718
# Processing batch 1318/1718
# Processing batch 1319/1718
# Processing batch 1320/1718
# Processing batch 1321/1718
# Processing batch 1322/1718
# Processing batch 1323/1718
# Processing batch 1324/1718
# Processing batch 1325/1718
# Processing batch 1326/1718
# Processing batch 1327/1718
# Processing batch 1328/1718
# Processing batch 1329/1718
# Processing batch 1330/1718
# Processing batch 1331/1718
# Processing batch 1332/1718
# Processing batch 1333/1718
# Processing batch 1334/1718
# Processing batch 1335/1718
# Processing batch 1336/1718
# Processing batch 1337/1718
# Processing batch 1338/1718
# Processing batch 1339/1718
# Processing batch 1340/1718
# Processing batch 1341/1718
# Processing batch 1342/1718
# Processing batch 1343/1718
# Processing batch 1344/1718
# Processing batch 1345/1718
# Processing batch 1346/1718
# Processing batch 1347/1718
# Processing batch 1348/1718
# Processing batch 1349/1718
# Processing batch 1350/1718
# Processing batch 1351/1718
# Processing batch 1352/1718
# Processing batch 1353/1718
# Processing batch 1354/1718
# Processing batch 1355/1718
# Processing batch 1356/1718
# Processing batch 1357/1718
# Processing batch 1358/1718
# Processing batch 1359/1718
# Processing batch 1360/1718
# Processing batch 1361/1718
# Processing batch 1362/1718
# Processing batch 1363/1718
# Processing batch 1364/1718
# Processing batch 1365/1718
# Processing batch 1366/1718
# Processing batch 1367/1718
# Processing batch 1368/1718
# Processing batch 1369/1718
# Processing batch 1370/1718
# Processing batch 1371/1718
# Processing batch 1372/1718
# Processing batch 1373/1718
# Processing batch 1374/1718
# Processing batch 1375/1718
# Processing batch 1376/1718
# Processing batch 1377/1718
# Processing batch 1378/1718
# Processing batch 1379/1718
# Processing batch 1380/1718
# Processing batch 1381/1718
# Processing batch 1382/1718
# Processing batch 1383/1718
# Processing batch 1384/1718
# Processing batch 1385/1718
# Processing batch 1386/1718
# Processing batch 1387/1718
# Processing batch 1388/1718
# Processing batch 1389/1718
# Processing batch 1390/1718
# Processing batch 1391/1718
# Processing batch 1392/1718
# Processing batch 1393/1718
# Processing batch 1394/1718
# Processing batch 1395/1718
# Processing batch 1396/1718
# Processing batch 1397/1718
# Processing batch 1398/1718
# Processing batch 1399/1718
# Processing batch 1400/1718
# Processing batch 1401/1718
# Processing batch 1402/1718
# Processing batch 1403/1718
# Processing batch 1404/1718
# Processing batch 1405/1718
# Processing batch 1406/1718
# Processing batch 1407/1718
# Processing batch 1408/1718
# Processing batch 1409/1718
# Processing batch 1410/1718
# Processing batch 1411/1718
# Processing batch 1412/1718
# Processing batch 1413/1718
# Processing batch 1414/1718
# Processing batch 1415/1718
# Processing batch 1416/1718
# Processing batch 1417/1718
# Processing batch 1418/1718
# Processing batch 1419/1718
# Processing batch 1420/1718
# Processing batch 1421/1718
# Processing batch 1422/1718
# Processing batch 1423/1718
# Processing batch 1424/1718
# Processing batch 1425/1718
# Processing batch 1426/1718
# Processing batch 1427/1718
# Processing batch 1428/1718
# Processing batch 1429/1718
# Processing batch 1430/1718
# Processing batch 1431/1718
# Processing batch 1432/1718
# Processing batch 1433/1718
# Processing batch 1434/1718
# Processing batch 1435/1718
# Processing batch 1436/1718
# Processing batch 1437/1718
# Processing batch 1438/1718
# Processing batch 1439/1718
# Processing batch 1440/1718
# Processing batch 1441/1718
# Processing batch 1442/1718
# Processing batch 1443/1718
# Processing batch 1444/1718
# Processing batch 1445/1718
# Processing batch 1446/1718
# Processing batch 1447/1718
# Processing batch 1448/1718
# Processing batch 1449/1718
# Processing batch 1450/1718
# Processing batch 1451/1718
# Processing batch 1452/1718
# Processing batch 1453/1718
# Processing batch 1454/1718
# Processing batch 1455/1718
# Processing batch 1456/1718
# Processing batch 1457/1718
# Processing batch 1458/1718
# Processing batch 1459/1718
# Processing batch 1460/1718
# Processing batch 1461/1718
# Processing batch 1462/1718
# Processing batch 1463/1718
# Processing batch 1464/1718
# Processing batch 1465/1718
# Processing batch 1466/1718
# Processing batch 1467/1718
# Processing batch 1468/1718
# Processing batch 1469/1718
# Processing batch 1470/1718
# Processing batch 1471/1718
# Processing batch 1472/1718
# Processing batch 1473/1718
# Processing batch 1474/1718
# Processing batch 1475/1718
# Processing batch 1476/1718
# Processing batch 1477/1718
# Processing batch 1478/1718
# Processing batch 1479/1718
# Processing batch 1480/1718
# Processing batch 1481/1718
# Processing batch 1482/1718
# Processing batch 1483/1718
# Processing batch 1484/1718
# Processing batch 1485/1718
# Processing batch 1486/1718
# Processing batch 1487/1718
# Processing batch 1488/1718
# Processing batch 1489/1718
# Processing batch 1490/1718
# Processing batch 1491/1718
# Processing batch 1492/1718
# Processing batch 1493/1718
# Processing batch 1494/1718
# Processing batch 1495/1718
# Processing batch 1496/1718
# Processing batch 1497/1718
# Processing batch 1498/1718
# Processing batch 1499/1718
# Processing batch 1500/1718
# Processing batch 1501/1718
# Processing batch 1502/1718
# Processing batch 1503/1718
# Processing batch 1504/1718
# Processing batch 1505/1718
# Processing batch 1506/1718
# Processing batch 1507/1718
# Processing batch 1508/1718
# Processing batch 1509/1718
# Processing batch 1510/1718
# Processing batch 1511/1718
# Processing batch 1512/1718
# Processing batch 1513/1718
# Processing batch 1514/1718
# Processing batch 1515/1718
# Processing batch 1516/1718
# Processing batch 1517/1718
# Processing batch 1518/1718
# Processing batch 1519/1718
# Processing batch 1520/1718
# Processing batch 1521/1718
# Processing batch 1522/1718
# Processing batch 1523/1718
# Processing batch 1524/1718
# Processing batch 1525/1718
# Processing batch 1526/1718
# Processing batch 1527/1718
# Processing batch 1528/1718
# Processing batch 1529/1718
# Processing batch 1530/1718
# Processing batch 1531/1718
# Processing batch 1532/1718
# Processing batch 1533/1718
# Processing batch 1534/1718
# Processing batch 1535/1718
# Processing batch 1536/1718
# Processing batch 1537/1718
# Processing batch 1538/1718
# Processing batch 1539/1718
# Processing batch 1540/1718
# Processing batch 1541/1718
# Processing batch 1542/1718
# Processing batch 1543/1718
# Processing batch 1544/1718
# Processing batch 1545/1718
# Processing batch 1546/1718
# Processing batch 1547/1718
# Processing batch 1548/1718
# Processing batch 1549/1718
# Processing batch 1550/1718
# Processing batch 1551/1718
# Processing batch 1552/1718
# Processing batch 1553/1718
# Processing batch 1554/1718
# Processing batch 1555/1718
# Processing batch 1556/1718
# Processing batch 1557/1718
# Processing batch 1558/1718
# Processing batch 1559/1718
# Processing batch 1560/1718
# Processing batch 1561/1718
# Processing batch 1562/1718
# Processing batch 1563/1718
# Processing batch 1564/1718
# Processing batch 1565/1718
# Processing batch 1566/1718
# Processing batch 1567/1718
# Processing batch 1568/1718
# Processing batch 1569/1718
# Processing batch 1570/1718
# Processing batch 1571/1718
# Processing batch 1572/1718
# Processing batch 1573/1718
# Processing batch 1574/1718
# Processing batch 1575/1718
# Processing batch 1576/1718
# Processing batch 1577/1718
# Processing batch 1578/1718
# Processing batch 1579/1718
# Processing batch 1580/1718
# Processing batch 1581/1718
# Processing batch 1582/1718
# Processing batch 1583/1718
# Processing batch 1584/1718
# Processing batch 1585/1718
# Processing batch 1586/1718
# Processing batch 1587/1718
# Processing batch 1588/1718
# Processing batch 1589/1718
# Processing batch 1590/1718
# Processing batch 1591/1718
# Processing batch 1592/1718
# Processing batch 1593/1718
# Processing batch 1594/1718
# Processing batch 1595/1718
# Processing batch 1596/1718
# Processing batch 1597/1718
# Processing batch 1598/1718
# Processing batch 1599/1718
# Processing batch 1600/1718
# Processing batch 1601/1718
# Processing batch 1602/1718
# Processing batch 1603/1718
# Processing batch 1604/1718
# Processing batch 1605/1718
# Processing batch 1606/1718
# Processing batch 1607/1718
# Processing batch 1608/1718
# Processing batch 1609/1718
# Processing batch 1610/1718
# Processing batch 1611/1718
# Processing batch 1612/1718
# Processing batch 1613/1718
# Processing batch 1614/1718
# Processing batch 1615/1718
# Processing batch 1616/1718
# Processing batch 1617/1718
# Processing batch 1618/1718
# Processing batch 1619/1718
# Processing batch 1620/1718
# Processing batch 1621/1718
# Processing batch 1622/1718
# Processing batch 1623/1718
# Processing batch 1624/1718
# Processing batch 1625/1718
# Processing batch 1626/1718
# Processing batch 1627/1718
# Processing batch 1628/1718
# Processing batch 1629/1718
# Processing batch 1630/1718
# Processing batch 1631/1718
# Processing batch 1632/1718
# Processing batch 1633/1718
# Processing batch 1634/1718
# Processing batch 1635/1718
# Processing batch 1636/1718
# Processing batch 1637/1718
# Processing batch 1638/1718
# Processing batch 1639/1718
# Processing batch 1640/1718
# Processing batch 1641/1718
# Processing batch 1642/1718
# Processing batch 1643/1718
# Processing batch 1644/1718
# Processing batch 1645/1718
# Processing batch 1646/1718
# Processing batch 1647/1718
# Processing batch 1648/1718
# Processing batch 1649/1718
# Processing batch 1650/1718
# Processing batch 1651/1718
# Processing batch 1652/1718
# Processing batch 1653/1718
# Processing batch 1654/1718
# Processing batch 1655/1718
# Processing batch 1656/1718
# Processing batch 1657/1718
# Processing batch 1658/1718
# Processing batch 1659/1718
# Processing batch 1660/1718
# Processing batch 1661/1718
# Processing batch 1662/1718
# Processing batch 1663/1718
# Processing batch 1664/1718
# Processing batch 1665/1718
# Processing batch 1666/1718
# Processing batch 1667/1718
# Processing batch 1668/1718
# Processing batch 1669/1718
# Processing batch 1670/1718
# Processing batch 1671/1718
# Processing batch 1672/1718
# Processing batch 1673/1718
# Processing batch 1674/1718
# Processing batch 1675/1718
# Processing batch 1676/1718
# Processing batch 1677/1718
# Processing batch 1678/1718
# Processing batch 1679/1718
# Processing batch 1680/1718
# Processing batch 1681/1718
# Processing batch 1682/1718
# Processing batch 1683/1718
# Processing batch 1684/1718
# Processing batch 1685/1718
# Processing batch 1686/1718
# Processing batch 1687/1718
# Processing batch 1688/1718
# Processing batch 1689/1718
# Processing batch 1690/1718
# Processing batch 1691/1718
# Processing batch 1692/1718
# Processing batch 1693/1718
# Processing batch 1694/1718
# Processing batch 1695/1718
# Processing batch 1696/1718
# Processing batch 1697/1718
# Processing batch 1698/1718
# Processing batch 1699/1718
# Processing batch 1700/1718
# Processing batch 1701/1718
# Processing batch 1702/1718
# Processing batch 1703/1718
# Processing batch 1704/1718
# Processing batch 1705/1718
# Processing batch 1706/1718
# Processing batch 1707/1718
# Processing batch 1708/1718
# Processing batch 1709/1718
# Processing batch 1710/1718
# Processing batch 1711/1718
# Processing batch 1712/1718
# Processing batch 1713/1718
# Processing batch 1714/1718
# Processing batch 1715/1718
# Processing batch 1716/1718
# Processing batch 1717/1718
# Processing batch 1718/1718

# %% [markdown]
# Merge the features and the photo IDs. The resulting files are `features.npy` and `photo_ids.csv`. Feel free to delete the intermediate results.

# %%
import numpy as np
import pandas as pd

# Load all numpy files
features_list = [np.load(features_file) for features_file in sorted(features_path.glob("*.npy"))]

# Concatenate the features and store in a merged file
features = np.concatenate(features_list)
np.save(features_path / "features.npy", features)

# Load all the photo IDs
photo_ids = pd.concat([pd.read_csv(ids_file) for ids_file in sorted(features_path.glob("*.csv"))])
photo_ids.to_csv(features_path / "photo_ids.csv", index=False)
